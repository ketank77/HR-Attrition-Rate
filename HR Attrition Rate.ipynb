# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Import required libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Set the default seaborn style for our plots
# seaborn default settings

# %%
sns.set()

# %% [markdown]
# ### Load and View the Employee Attrition Data

# %%
import os
os.chdir('C:\\GL Class\EDA Session')
df_emp = pd.read_csv('HR_Employee_Attrition.csv')

# %%
df_emp.head()
# Out:
#    EmployeeNumber  Gender  Age Attrition     BusinessTravel  \
# 0               1  Female   41       Yes      Travel_Rarely
# 1               2    Male   49        No  Travel_Frequently
# 2               4    Male   37       Yes      Travel_Rarely
# 3               5  Female   33        No  Travel_Frequently
# 4               7    Male   27        No      Travel_Rarely
#
#                Department  DistanceFromHome EducationField  \
# 0                   Sales                 1  Life Sciences
# 1  Research & Development                 8  Life Sciences
# 2  Research & Development                 2          Other
# 3  Research & Development                 3  Life Sciences
# 4  Research & Development                 2        Medical
#
#    EnvironmentSatisfaction  HourlyRate  ... OverTime  PercentSalaryHike  \
# 0                        2        94.0  ...      Yes                 11
# 1                        3        61.0  ...       No                 23
# 2                        4        92.0  ...      Yes                 15
# 3                        4        56.0  ...      Yes                 11
# 4                        1        40.0  ...       No                 12
#
#   PerformanceRating  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0               3.0                  8                      0               1
# 1               4.0                 10                      3               3
# 2               3.0                  7                      3               3
# 3               3.0                  8                      3               3
# 4               3.0                  6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 25 columns]

# %%
df_emp.tail()
# Out:
#       EmployeeNumber Gender  Age Attrition     BusinessTravel  \
# 1465            2061   Male   36        No  Travel_Frequently
# 1466            2062   Male   39        No      Travel_Rarely
# 1467            2064   Male   27        No      Travel_Rarely
# 1468            2065   Male   49        No  Travel_Frequently
# 1469            2068   Male   34        No      Travel_Rarely
#
#                   Department  DistanceFromHome EducationField  \
# 1465  Research & Development                23        Medical
# 1466  Research & Development                 6        Medical
# 1467  Research & Development                 4  Life Sciences
# 1468                   Sales                 2        Medical
# 1469  Research & Development                 8        Medical
#
#       EnvironmentSatisfaction  HourlyRate  ... OverTime  PercentSalaryHike  \
# 1465                        3        41.0  ...       No                 17
# 1466                        4        42.0  ...       No                 15
# 1467                        2        87.0  ...      Yes                 20
# 1468                        4        63.0  ...       No                 14
# 1469                        2        82.0  ...       No                 12
#
#      PerformanceRating  TotalWorkingYears  TrainingTimesLastYear  \
# 1465               3.0                 17                      3
# 1466               3.0                  9                      5
# 1467               4.0                  6                      0
# 1468               3.0                 17                      3
# 1469               3.0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 1465               3               5                   2
# 1466               3               7                   7
# 1467               3               6                   2
# 1468               2               9                   6
# 1469               4               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [5 rows x 25 columns]

# %% [markdown]
# View field list with data type

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeNumber           1470 non-null   int64
#  1   Gender                   1470 non-null   object
#  2   Age                      1470 non-null   int64
#  3   Attrition                1470 non-null   object
#  4   BusinessTravel           1470 non-null   object
#  5   Department               1470 non-null   object
#  6   DistanceFromHome         1470 non-null   int64
#  7   EducationField           1470 non-null   object
#  8   EnvironmentSatisfaction  1470 non-null   int64
#  9   HourlyRate               1469 non-null   float64
#  10  JobRole                  1470 non-null   object
#  11  JobSatisfaction          1470 non-null   int64
#  12  MaritalStatus            1470 non-null   object
#  13  MonthlyIncome            1470 non-null   int64
#  14  NumCompaniesWorked       1470 non-null   int64
#  15  OverTime                 1470 non-null   object
#  16  PercentSalaryHike        1470 non-null   int64
#  17  PerformanceRating        1469 non-null   float64
#  18  TotalWorkingYears        1470 non-null   int64
#  19  TrainingTimesLastYear    1470 non-null   int64
#  20  WorkLifeBalance          1470 non-null   int64
#  21  YearsAtCompany           1470 non-null   int64
#  22  YearsInCurrentRole       1470 non-null   int64
#  23  YearsSinceLastPromotion  1470 non-null   int64
#  24  YearsWithCurrManager     1470 non-null   int64
# dtypes: float64(2), int64(15), object(8)
# memory usage: 287.2+ KB

# %%
df_emp.describe(include='all')
# Out:
#         EmployeeNumber Gender          Age Attrition BusinessTravel  \
# count      1470.000000   1470  1470.000000      1470           1470
# unique             NaN      2          NaN         2              3
# top                NaN   Male          NaN        No  Travel_Rarely
# freq               NaN    882          NaN      1233           1043
# mean       1024.865306    NaN    36.923810       NaN            NaN
# std         602.024335    NaN     9.135373       NaN            NaN
# min           1.000000    NaN    18.000000       NaN            NaN
# 25%         491.250000    NaN    30.000000       NaN            NaN
# 50%        1020.500000    NaN    36.000000       NaN            NaN
# 75%        1555.750000    NaN    43.000000       NaN            NaN
# max        2068.000000    NaN    60.000000       NaN            NaN
#
#                     Department  DistanceFromHome EducationField  \
# count                     1470       1470.000000           1470
# unique                       3               NaN              6
# top     Research & Development               NaN  Life Sciences
# freq                       961               NaN            606
# mean                       NaN          9.192517            NaN
# std                        NaN          8.106864            NaN
# min                        NaN          1.000000            NaN
# 25%                        NaN          2.000000            NaN
# 50%                        NaN          7.000000            NaN
# 75%                        NaN         14.000000            NaN
# max                        NaN         29.000000            NaN
#
#         EnvironmentSatisfaction   HourlyRate  ... OverTime  PercentSalaryHike  \
# count               1470.000000  1469.000000  ...     1470        1470.000000
# unique                      NaN          NaN  ...        2                NaN
# top                         NaN          NaN  ...       No                NaN
# freq                        NaN          NaN  ...     1054                NaN
# mean                   2.721769    65.886998  ...      NaN          15.209524
# std                    1.093082    20.335725  ...      NaN           3.659938
# min                    1.000000    30.000000  ...      NaN          11.000000
# 25%                    2.000000    48.000000  ...      NaN          12.000000
# 50%                    3.000000    66.000000  ...      NaN          14.000000
# 75%                    4.000000    84.000000  ...      NaN          18.000000
# max                    4.000000   100.000000  ...      NaN          25.000000
#
#        PerformanceRating  TotalWorkingYears  TrainingTimesLastYear  \
# count        1469.000000        1470.000000            1470.000000
# unique               NaN                NaN                    NaN
# top                  NaN                NaN                    NaN
# freq                 NaN                NaN                    NaN
# mean            3.153846          11.279592               2.799320
# std             0.360924           7.780782               1.289271
# min             3.000000           0.000000               0.000000
# 25%             3.000000           6.000000               2.000000
# 50%             3.000000          10.000000               3.000000
# 75%             3.000000          15.000000               3.000000
# max             4.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# unique             NaN             NaN                 NaN
# top                NaN             NaN                 NaN
# freq               NaN             NaN                 NaN
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#         YearsSinceLastPromotion  YearsWithCurrManager
# count               1470.000000           1470.000000
# unique                      NaN                   NaN
# top                         NaN                   NaN
# freq                        NaN                   NaN
# mean                   2.187755              4.123129
# std                    3.222430              3.568136
# min                    0.000000              0.000000
# 25%                    0.000000              2.000000
# 50%                    1.000000              3.000000
# 75%                    3.000000              7.000000
# max                   15.000000             17.000000
#
# [11 rows x 25 columns]

# %% [markdown]
# As we have few ordinal fields with ratings provided in numeric form, let us first convert them to object form

# %%
df_emp.EnvironmentSatisfaction = df_emp.EnvironmentSatisfaction.astype('object')
df_emp.JobSatisfaction = df_emp.JobSatisfaction.astype('object')
df_emp.PerformanceRating = df_emp.PerformanceRating.astype('object')
df_emp.WorkLifeBalance = df_emp.WorkLifeBalance.astype('object')
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeNumber           1470 non-null   int64
#  1   Gender                   1470 non-null   object
#  2   Age                      1470 non-null   int64
#  3   Attrition                1470 non-null   object
#  4   BusinessTravel           1470 non-null   object
#  5   Department               1470 non-null   object
#  6   DistanceFromHome         1470 non-null   int64
#  7   EducationField           1470 non-null   object
#  8   EnvironmentSatisfaction  1470 non-null   object
#  9   HourlyRate               1469 non-null   float64
#  10  JobRole                  1470 non-null   object
#  11  JobSatisfaction          1470 non-null   object
#  12  MaritalStatus            1470 non-null   object
#  13  MonthlyIncome            1470 non-null   int64
#  14  NumCompaniesWorked       1470 non-null   int64
#  15  OverTime                 1470 non-null   object
#  16  PercentSalaryHike        1470 non-null   int64
#  17  PerformanceRating        1469 non-null   object
#  18  TotalWorkingYears        1470 non-null   int64
#  19  TrainingTimesLastYear    1470 non-null   int64
#  20  WorkLifeBalance          1470 non-null   object
#  21  YearsAtCompany           1470 non-null   int64
#  22  YearsInCurrentRole       1470 non-null   int64
#  23  YearsSinceLastPromotion  1470 non-null   int64
#  24  YearsWithCurrManager     1470 non-null   int64
# dtypes: float64(1), int64(12), object(12)
# memory usage: 287.2+ KB

# %% [markdown]
# ### Missing Data Treatment

# %%
df_emp.isnull().sum()
# Out:
# EmployeeNumber             0
# Gender                     0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# EducationField             0
# EnvironmentSatisfaction    0
# HourlyRate                 1
# JobRole                    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          1
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %% [markdown]
# #### 1 missing value each in 'HourlyRate' field and 'PerformanceRating' field

# %%
df_emp.PerformanceRating.value_counts()
# Out:
# 3.0    1243
# 4.0     226
# Name: PerformanceRating, dtype: int64

# %%
df_emp.PerformanceRating.mode()
# Out:
# 0    3
# dtype: object

# %%
df_emp.PerformanceRating.mode()[0]
# Out:
# 3.0

# %%
df_emp['PerformanceRating'].fillna(df_emp['PerformanceRating'].mode()[0], inplace=True)

# %%
df_emp['HourlyRate'].describe()
# Out:
# count    1469.000000
# mean       65.886998
# std        20.335725
# min        30.000000
# 25%        48.000000
# 50%        66.000000
# 75%        84.000000
# max       100.000000
# Name: HourlyRate, dtype: float64

# %%
sns.boxplot(x='HourlyRate',data=df_emp)

# %% [markdown]
# No outliers observed and mean(65.88) and median(66) are very near to each other

# %%
df_emp['HourlyRate'].fillna(df_emp['HourlyRate'].mean(), inplace=True)

# %% [markdown]
# #### Check if all values are updated and the dataset is clean to proceed

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeNumber           1470 non-null   int64
#  1   Gender                   1470 non-null   object
#  2   Age                      1470 non-null   int64
#  3   Attrition                1470 non-null   object
#  4   BusinessTravel           1470 non-null   object
#  5   Department               1470 non-null   object
#  6   DistanceFromHome         1470 non-null   int64
#  7   EducationField           1470 non-null   object
#  8   EnvironmentSatisfaction  1470 non-null   object
#  9   HourlyRate               1470 non-null   float64
#  10  JobRole                  1470 non-null   object
#  11  JobSatisfaction          1470 non-null   object
#  12  MaritalStatus            1470 non-null   object
#  13  MonthlyIncome            1470 non-null   int64
#  14  NumCompaniesWorked       1470 non-null   int64
#  15  OverTime                 1470 non-null   object
#  16  PercentSalaryHike        1470 non-null   int64
#  17  PerformanceRating        1470 non-null   float64
#  18  TotalWorkingYears        1470 non-null   int64
#  19  TrainingTimesLastYear    1470 non-null   int64
#  20  WorkLifeBalance          1470 non-null   object
#  21  YearsAtCompany           1470 non-null   int64
#  22  YearsInCurrentRole       1470 non-null   int64
#  23  YearsSinceLastPromotion  1470 non-null   int64
#  24  YearsWithCurrManager     1470 non-null   int64
# dtypes: float64(2), int64(12), object(11)
# memory usage: 287.2+ KB

# %% [markdown]
# PerformanceRating field is changed to float64 as numeric value (mode) was assigned to the missing data. Hence we have to change it back to object type
#
# Also EmployeeNumber is a unique identifier and hence we will not need it.

# %%
df_emp.PerformanceRating = df_emp.PerformanceRating.astype('object') 
df_emp.drop(['EmployeeNumber'], axis = 1, inplace=True)

# %%
df_emp.shape
# Out:
# (1470, 24)

# %%
df_emp.Department.value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df_emp.Department.value_counts(normalize=True)
# Out:
# Research & Development    0.653741
# Sales                     0.303401
# Human Resources           0.042857
# Name: Department, dtype: float64

# %%
df_emp.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df_emp.Attrition.value_counts(normalize=True)
# Out:
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64

# %% [markdown]
# #### Data Summary:
#
# •	HR Attrition dataset has 1470 observations for 25 features.
#
# •	EmployeeNumber is an ID field which can be ignored. Apart from this there are 12 numeric and 11 categorical variables (Note: Ordinal fields like ‘PerformanceRating’, ‘WorkLifeBalance’ etc. are converted into categorical variables)
#
# •	Data is provided for both male and female employees between age group of 18years to 60 years.
#
# •	Employees are from 6 different EducationField, are part of 3 Departments and play 9 different job roles.
#
# •	961 out of 1470 employees (65%) are from ‘Research and Development’ department.
#
# •	1233 out of 1470 employees are still with the company. Hence, we have only 237 (16%) observations corresponding to employees who have left the company.
#
# •	Important information with regards to PerformanceRating, JobSatisfaction, WorkLifeBalance etc. has been provided which can be probable factors for the attrition.
#
# •	2 missing information observed in the dataset has been treated by imputing relevant statistic values.

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Numeric Fields

# %% [markdown]
# Get the statistics for the numeric field

# %%
df_emp['Age'].describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %% [markdown]
# Set the figure size dimensions
#
# Create subplots to incorporate 2 plots(columns) in 1 row
#
# Histogram (bins adjusted based on the distribution spread)
#
# Boxplot

# %%
fig_dims = (10, 5) 
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=fig_dims) 
sns.distplot(df_emp.Age, kde=True, ax=axs[0]) 
sns.boxplot(x= 'Age', data=df_emp, ax=axs[1])

# %% [markdown]
# Age of employees ranges from 18 through 60 years with mean age of 36-37 years. Age field is normally distributed and has no outliers

# %%
df_emp['MonthlyIncome'].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
#  distplot -> rugplot introduced- plot of each datapoint.. Distribution of data points.

# %%
fig_dims = (10, 5)
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=fig_dims)
sns.distplot(df_emp.MonthlyIncome, rug= True, kde=False, ax=axs[0]) 
sns.boxplot(x= 'MonthlyIncome', data=df_emp, color = 'm',ax=axs[1])

# %% [markdown]
# Monthly Income of the employees ranges from 1009 through 19999. Distribution is right skewed with outliers beyond a value of 16581.

# %%
df_emp['YearsAtCompany'].describe()
# Out:
# count    1470.000000
# mean        7.008163
# std         6.126525
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64

# %% [markdown]
# distplot -> Kernel Density Estimation (KDE) - estimate the probability density function of a continuous random variable

# %%
fig_dims = (10, 5)
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=fig_dims)
sns.distplot(df_emp.YearsAtCompany, kde=True, ax=axs[0]) 
sns.boxplot(x= 'YearsAtCompany', data=df_emp, ax=axs[1])

# %% [markdown]
# Data is provided for employees who have joined recently up to those who are with the company for 40 years. Average experience of the employees is around 7 years. Distribution of this data is right skewed indicating there are few employees in the company who are with the company for more than 18 years. Q3+1.5*IQR = 9+1.5*(9-3)=9+9=18

# %%
df_emp['PercentSalaryHike'].describe()
# Out:
# count    1470.000000
# mean       15.209524
# std         3.659938
# min        11.000000
# 25%        12.000000
# 50%        14.000000
# 75%        18.000000
# max        25.000000
# Name: PercentSalaryHike, dtype: float64

# %%
fig_dims = (10, 5)
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=fig_dims)
sns.distplot(df_emp.PercentSalaryHike, kde=False, ax=axs[0])
sns.boxplot(x= 'PercentSalaryHike', data=df_emp, ax=axs[1], orient = 'v')

# %% [markdown]
# PercentSalaryHike ranges between 11% to 25% with average hike around 14-15%. Distribution is right skewed with no outliers.

# %% [markdown]
# #### Categorical Fields

# %% [markdown]
# ##### Define Function for univariate analysis of categorical variable

# %%
def univariateAnalysis_category(cat_column):
    print("Details of " + cat_column)
    print("----------------------------------------------------------------")
    print(df_emp[cat_column].value_counts())
    sns.countplot(x=cat_column, data=df_emp, palette='pastel')
    plt.show()
    print("       ")

# %% [markdown]
# Pick up all categorical fields from the data

# %%
df_emp_object = df_emp.select_dtypes(include = ['object']) 
lstcatcolumns = list(df_emp_object.columns.values)
lstcatcolumns
# Out:
# ['Gender',
#  'Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'EnvironmentSatisfaction',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'OverTime',
#  'PerformanceRating',
#  'WorkLifeBalance']

# %% [markdown]
# Call the defined function to print countplot for all categorical fields

# %%
for x in lstcatcolumns:
    univariateAnalysis_category(x)
# Out:
# Details of Gender
# ----------------------------------------------------------------
# Male      882
# Female    588
# Name: Gender, dtype: int64
#
# Details of Attrition
# ----------------------------------------------------------------
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
#
# Details of BusinessTravel
# ----------------------------------------------------------------
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
# Details of Department
# ----------------------------------------------------------------
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
#
# Details of EducationField
# ----------------------------------------------------------------
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
#
# Details of EnvironmentSatisfaction
# ----------------------------------------------------------------
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64
#
# Details of JobRole
# ----------------------------------------------------------------
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
#
# Details of JobSatisfaction
# ----------------------------------------------------------------
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64
#
# Details of MaritalStatus
# ----------------------------------------------------------------
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
#
# Details of OverTime
# ----------------------------------------------------------------
# No     1054
# Yes     416
# Name: OverTime, dtype: int64
#
# Details of PerformanceRating
# ----------------------------------------------------------------
# 3.0    1244
# 4.0     226
# Name: PerformanceRating, dtype: int64
#
# Details of WorkLifeBalance
# ----------------------------------------------------------------
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
sns.catplot(y='JobRole', kind='count', aspect=2, data=df_emp)
# aspect signifies the width of each bar

# %%
ax = sns.countplot(x="EducationField", data=df_emp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
# Out:
# [Text(0, 0, 'Life Sciences'),
#  Text(0, 0, 'Other'),
#  Text(0, 0, 'Medical'),
#  Text(0, 0, 'Marketing'),
#  Text(0, 0, 'Technical Degree'),
#  Text(0, 0, 'Human Resources')]

# %% [markdown]
# •	882 out of 1470 are male employees. 60:40 ratio of male to female employees in the company.
#
# •	Company provide opportunity for BusinessTravel. 277 out of 1470 i.e 19% of the employees have frequent travel opportunity.
#
# •	Around 61%(453+446) employees have given 3 and above rating  (‘High’ or ‘Very High’) for Environment Satisfaction
#
# •	416 employees i.e. 28% of the employees contribute to overtime services.
#
# •	All employees seem to get a high rating of 3 and above (Excellent or Outstanding)

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Numeric & Numeric

# %% [markdown]
# Pick up all numeric fields from dataset for analysis

# %%
df_emp_numeric = df_emp.select_dtypes(include = ['int64','float64'])
df_emp_numeric.shape
# Out:
# (1470, 12)

# %%
sns.pairplot(df_emp_numeric)

# %% [markdown]
# From above plots we observe possible relation between few fields Age, Monthly Income, Total Working Years etc.

# %%
fig_dims = (10, 5)
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=fig_dims)
sns.scatterplot(x='Age', y='MonthlyIncome', data=df_emp,ax= axs[0])
sns.scatterplot(x='TotalWorkingYears', y='MonthlyIncome', data=df_emp,ax= axs[1])

# %% [markdown]
# •	Scatterplot of Age against Monthly Income shows that as Age increases Monthly Income has also increased. However, range of income for employees between 30-40 spreads spreads from minimum of 2500 to above 15000.
#
# •	Plot on Total Working Years and Monthly Income indicates that most of the employees beyond 20 years of work experience have a salary above 15000.

# %% [markdown]
# Get correlation between numeric fields

# %%
corr = df_emp_numeric.corr()
round(corr,2)
# Out:
#                           Age  DistanceFromHome  HourlyRate  MonthlyIncome  \
# Age                      1.00             -0.00        0.02           0.50
# DistanceFromHome        -0.00              1.00        0.03          -0.02
# HourlyRate               0.02              0.03        1.00          -0.02
# MonthlyIncome            0.50             -0.02       -0.02           1.00
# NumCompaniesWorked       0.30             -0.03        0.02           0.15
# PercentSalaryHike        0.00              0.04       -0.01          -0.03
# TotalWorkingYears        0.68              0.00       -0.00           0.77
# TrainingTimesLastYear   -0.02             -0.04       -0.01          -0.02
# YearsAtCompany           0.31              0.01       -0.02           0.51
# YearsInCurrentRole       0.21              0.02       -0.02           0.36
# YearsSinceLastPromotion  0.22              0.01       -0.03           0.34
# YearsWithCurrManager     0.20              0.01       -0.02           0.34
#
#                          NumCompaniesWorked  PercentSalaryHike  \
# Age                                    0.30               0.00
# DistanceFromHome                      -0.03               0.04
# HourlyRate                             0.02              -0.01
# MonthlyIncome                          0.15              -0.03
# NumCompaniesWorked                     1.00              -0.01
# PercentSalaryHike                     -0.01               1.00
# TotalWorkingYears                      0.24              -0.02
# TrainingTimesLastYear                 -0.07              -0.01
# YearsAtCompany                        -0.12              -0.04
# YearsInCurrentRole                    -0.09              -0.00
# YearsSinceLastPromotion               -0.04              -0.02
# YearsWithCurrManager                  -0.11              -0.01
#
#                          TotalWorkingYears  TrainingTimesLastYear  \
# Age                                   0.68                  -0.02
# DistanceFromHome                      0.00                  -0.04
# HourlyRate                           -0.00                  -0.01
# MonthlyIncome                         0.77                  -0.02
# NumCompaniesWorked                    0.24                  -0.07
# PercentSalaryHike                    -0.02                  -0.01
# TotalWorkingYears                     1.00                  -0.04
# TrainingTimesLastYear                -0.04                   1.00
# YearsAtCompany                        0.63                   0.00
# YearsInCurrentRole                    0.46                  -0.01
# YearsSinceLastPromotion               0.40                  -0.00
# YearsWithCurrManager                  0.46                  -0.00
#
#                          YearsAtCompany  YearsInCurrentRole  \
# Age                                0.31                0.21
# DistanceFromHome                   0.01                0.02
# HourlyRate                        -0.02               -0.02
# MonthlyIncome                      0.51                0.36
# NumCompaniesWorked                -0.12               -0.09
# PercentSalaryHike                 -0.04               -0.00
# TotalWorkingYears                  0.63                0.46
# TrainingTimesLastYear              0.00               -0.01
# YearsAtCompany                     1.00                0.76
# YearsInCurrentRole                 0.76                1.00
# YearsSinceLastPromotion            0.62                0.55
# YearsWithCurrManager               0.77                0.71
#
#                          YearsSinceLastPromotion  YearsWithCurrManager
# Age                                         0.22                  0.20
# DistanceFromHome                            0.01                  0.01
# HourlyRate                                 -0.03                 -0.02
# MonthlyIncome                               0.34                  0.34
# NumCompaniesWorked                         -0.04                 -0.11
# PercentSalaryHike                          -0.02                 -0.01
# TotalWorkingYears                           0.40                  0.46
# TrainingTimesLastYear                      -0.00                 -0.00
# YearsAtCompany                              0.62                  0.77
# YearsInCurrentRole                          0.55                  0.71
# YearsSinceLastPromotion                     1.00                  0.51
# YearsWithCurrManager                        0.51                  1.00

# %% [markdown]
# Generate a mask for the upper triangle before plotting the heatmap

# %%
fig_dims = (10, 6)
#fig = plt.subplots(figsize=fig_dims)
#mask = np.triu(np.ones_like(corr, dtype=np.bool)) 
sns.heatmap(round(corr,2), annot=True, mask=(np.triu(corr,+1)))

# %% [markdown]
# •	Positive correlation is observed between the numeric fields. ‘TotalWorkingYears’ & ‘MonthlyIncome’; ‘YearsInCurrentRole’ & ‘YearsAtCompany’; ‘YearsWithCurrManager’ & ‘YearsAtCompany’; ‘YearsInCurrentRole’ & ‘YearsWithCurrManager’ have a correlation of more than 70%

# %% [markdown]
# #### Categorical & Categorical

# %%
sns.countplot(x='Attrition', hue='Gender', data=df_emp)

# %% [markdown]
# •	Attrition more by male employees compared to female employees.

# %%
sns.countplot(y='OverTime', hue='Attrition', data=df_emp)

# %% [markdown]
# •	More attrition observed in employees who do overtime.

# %%
#pd.crosstab(df_emp.Attrition, df_emp.EducationField, margins=True, normalize='columns')
pd.crosstab(df_emp.Attrition, df_emp.EducationField)
# Out:
# EducationField  Human Resources  Life Sciences  Marketing  Medical  Other  \
# Attrition
# No                           20            517        124      401     71
# Yes                           7             89         35       63     11
#
# EducationField  Technical Degree
# Attrition
# No                           100
# Yes                           32

# %% [markdown]
# •	Count-wise maximum number of attrition observed in employee with ‘Life Sciences’ and 'Medical' education field.
#
# •	However, if we consider each department 26% attrition observed in Human Resources department

# %%
pd.crosstab(df_emp.Attrition, df_emp.JobSatisfaction, margins=True)
# Out:
# JobSatisfaction    1    2    3    4   All
# Attrition
# No               223  234  369  407  1233
# Yes               66   46   73   52   237
# All              289  280  442  459  1470

# %%
pd.crosstab(df_emp.Attrition, df_emp.JobSatisfaction, normalize='columns')
# Out:
# JobSatisfaction         1         2         3        4
# Attrition
# No               0.771626  0.835714  0.834842  0.88671
# Yes              0.228374  0.164286  0.165158  0.11329

# %%
pd.crosstab(df_emp.Attrition, df_emp.JobSatisfaction, margins=True, normalize=True)
# Out:
# JobSatisfaction         1         2        3         4       All
# Attrition
# No               0.151701  0.159184  0.25102  0.276871  0.838776
# Yes              0.044898  0.031293  0.04966  0.035374  0.161224
# All              0.196599  0.190476  0.30068  0.312245  1.000000

# %% [markdown]
# •	Maximum employees given a rating of 3 or 4 (61%). Attrition higher in employees who have given low rating of 1 or 2.

# %% [markdown]
# #### Categorical & Numeric

# %%
fig_dims = (12, 5)
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=fig_dims)
sns.boxplot(x='Attrition', y='MonthlyIncome', data=df_emp, ax=axs[0])
sns.boxplot(x='Attrition', y='Age', data=df_emp, ax=axs[1])
sns.boxplot(x='Attrition', y='DistanceFromHome', data=df_emp, ax=axs[2])

# %% [markdown]
# •	Average and range of monthly income of attrite employees is much lesser.
#
# •	Younger employees, average age of around 32 are leaving the company.
#
# •	Employees who stay at far away places seem to be leaving the company.

# %% [markdown]
# ### Multivariate Analysis

# %%
fig_dims = (12, 6)
fig = plt.subplots(figsize=fig_dims)
sns.scatterplot(x='NumCompaniesWorked', y='TotalWorkingYears', hue='Attrition', data=df_emp)

# %% [markdown]
# Attrition more by employees who have worked in many companies (3 and above) and have lesser then 20 years of working experience.

# %%
fig_dims = (12, 6)
fig = plt.subplots(figsize=fig_dims)
sns.boxplot(x='Attrition', y='YearsAtCompany', hue='BusinessTravel',data=df_emp)

# %% [markdown]
# •	Attrite employees have been with the company for around 2.5 years on an average.

# %% [markdown]
# ### Facetgrid

# %%
g = sns.FacetGrid(df_emp, col="JobRole", hue='Attrition',col_wrap=3, height=3)
g = g.map(plt.scatter, "YearsSinceLastPromotion", 'YearsAtCompany')

# %% [markdown]
# •	More attrition observed for Job Role of Sales Executive. Attrition has occurred for employees who have been with the company for more than 5-6 years and have not been promoted for more than 2-3 years.

# %% [markdown]
# ### Summary
# •	Company has fair spread of employees across age group (18 through 60) and gender (60:40 ratio of male vs female).
#
# •	Fields like Monthly Income have outliers - max value being 19999. Need to check if outlier treatment will be required while building predictive models.
#
# •	More than 60% employees seem to be satisfied with the job and working environment.
#
# •	PerformanceRating paramter has only 2 levels corresponding to Excellent and Outstanding. Observation to be shared with HR department.
#
# •	16% of the observations correspond to the Attrition.
#
# •	Attrition observed more in male employees and also in employees who work overtime.
#
# •	Distance from work also seems to be a factor for attrition.
#
# •	Higher attrition observed in employees who are Sales Executive and delay in promotion seems to reason for the same.
